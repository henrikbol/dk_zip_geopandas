# %%
import geopandas
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
zip = geopandas.read_file("geo_data/POSTNUMMER.shp")[
    ["POSTNR_TXT", "POSTBYNAVN", "POSTNR_FRA", "POSTNR_TIL", "geometry"]
]

zip["data"] = np.random.randint(100, size=zip.shape[0])  # Generate some data to plot

# %%
zip.sample(5)
# Out:
#     POSTNR_TXT  POSTBYNAVN POSTNR_FRA POSTNR_TIL  \
# 384       4880      Nysted       4880       4880
# 58        8960  Randers SØ       8960       8960
# 114       5620  Glamsbjerg       5620       5620
# 392       5631     Ebberup       5631       5631
# 63        5601         Lyø       5601       5601
#
#                                               geometry  data
# 384  POLYGON Z ((669529.470 6066640.000 -999.000, 6...    62
# 58   POLYGON Z ((574870.080 6259520.300 -999.000, 5...    82
# 114  POLYGON Z ((564963.820 6133808.290 -999.000, 5...    33
# 392  POLYGON Z ((563062.970 6117531.010 -999.000, 5...    66
# 63   POLYGON Z ((571853.350 6101429.840 -999.000, 5...    94

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
plt.axis("off")
zip.plot(column="data", legend=True, ax=ax, edgecolor=None);
