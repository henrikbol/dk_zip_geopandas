# %%
import geopandas
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
zip = geopandas.read_file("POSTNUMMER.shp")[
    ["POSTNR_TXT", "POSTBYNAVN", "POSTNR_FRA", "POSTNR_TIL", "geometry"]
]

zip["data"] = np.random.randint(100, size=zip.shape[0])  # Generate some data to plot

# %%
zip.sample(5)
# Out:
#     POSTNR_TXT  POSTBYNAVN POSTNR_FRA POSTNR_TIL  \
# 290       8961  Allingåbro       8961       8961
# 520       9270      Klarup       9270       9270
# 725       7960       Karby       7960       7960
# 380       5330     Munkebo       5330       5330
# 27        9520    Skørping       9520       9520
#
#                                               geometry  data
# 290  POLYGON Z ((588729.340 6265198.270 -999.000, 5...    62
# 520  POLYGON Z ((562020.480 6319030.350 -999.000, 5...    29
# 725  POLYGON Z ((472060.360 6285707.930 -999.000, 4...    67
# 380  POLYGON Z ((594174.380 6146524.410 -999.000, 5...    61
# 27   POLYGON Z ((557970.390 6306943.210 -999.000, 5...    23

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
plt.axis("off")
zip.plot(column="data", legend=True, ax=ax, edgecolor=None);
